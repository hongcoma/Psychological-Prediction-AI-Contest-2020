# %% [markdown]
# # 마키아벨리니즘 테스트 문항
# - A : Secret
# - B : 범죄자들과 다른 일반 사람들의 가장 큰 차이점은, 범죄자들이 잡힐만큼 멍청하다는 것이다.
# - C : 누군가를 완전히 믿는 사람은 고생을 자처하는 것이다.
# - D : Secret
# - E : P.T. Barnum이 '매 분마다 선천적으로 잘 속는 사람이 태어난다' 라고 말한 것은 틀립니다.
# - F : 누군가에게 거짓말을 하는 것은 변명의 여지가 없다.
# - G : Secret
# - H : 대부분의 사람들은 그들의 재산을 잃은 것보다 부모의 죽음을 더 빨리 잊는다.
# - I : Secret
# - J : 모든 사람에게는 악한 경향이 있고, 기회만 주어진다면 그 성향이 표현된다고 가정하는것이 가장 안전하다.
# - K : 대체로 겸손하고 정직한 것이, 중요하고 부정직 한것보다 낫다.
# - L : Secret
# - M : 여기저기를 질러가지 않는다면 앞으로 나아가기 힘들다 (요령이 없다면 앞으로 나아가기 힘들다).
# - N : Secret
# - O : 사람을 다루는 가장 좋은 방법은 그들이 듣기 원하는 말을 해주는 것이다.
# - P : Secret
# - Q : 대부분의 사람들은 기본적으로 선하며, 착하다.
# - R : 도덕적으로 올바른 일 일때만, 그 행동을 해야 한다.
# - S : 중요한 사람들(자신의 상관, 정부의 요인들 등등)애개 아첨하는것이 현명하다.
# - T : Secret
#
# ### 비 식별화를 위해 Secret 처리된 문항
# - Never tell anyone the real reason you did something unless it is useful to do so.
# - 당신이 어떤 일을 한 이유를 필요할 때를 제외하고는 누구에게도 절대 말하지 않는다.
#
# - Honesty is the best policy in all cases.
# - 모든 케이스에 있어서 정직이 최선이다.
#
# - Generally speaking, people won't work hard unless they're forced to do so.
# - 일반적으로, 사람들을 강제하지 않는 한, 열심히 일하지 않는다.
#
# - When you ask someone to do something for you, it is best to give the real reasons for wanting it rather than giving reasons which carry more weight.
# - 어떤 일을 해달라고 누군가에게 요청할 때, 내가 그 일을 원하는 실제 이유를 알려주는 것이, 더 중요해보이는 듯한 이유를 알려주는 것보다 가장 좋은 방법이다.
#
# - Most people who get ahead in the world lead clean, moral lives.
# - 세상을 앞에서 이끌어가는 사람들은 깨끗하고 도덕적인 삶을 산다.
#
# - Most people are brave.
# - 대부분의 사람들은 용감하다.
#
# - It is possible to be good in all respects.
# - 모든 면에서 좋은 것이 가능하다.
#
# - People suffering from incurable diseases should have the choice of being put painlessly to death.
# - 불치병에 걸린 사람들에게 안락사를 선택할 권리를 갖게 해야 한다.

# %% [markdown]
# # 시각화

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set() # setting seaborn default for plots

def bar_chart(feature):
    yes = train[train['voted']==1][feature].value_counts()
    no = train[train['voted']==2][feature].value_counts()
    df = pd.DataFrame([yes,no])
    df.index = ['Yes','No']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %% [markdown]
# - tp01 : extraverted (외향적), enthusiastic (열광적인)
# - tp02 : critical (비판적인), quarrelsome (걸핏하면 싸우려 드는)
# - tp03 : dependable (믿을 수 있는), self-disciplined (자기훈련이 된)
# - tp04 : anxious (불안해하는), easily upset (쉽게 흥분하는)
# - tp05 : open to new experiences, complex (새로운 경험, 집합체에 열려있는)
# - tp06 : reserved (내성적인), quiet (조용한)
# - tp07 : sympathetic (공감하는, 호감가는), warm (따뜻한)
# - tp08 : disorganized (체계적이지 않은), careless (부주의한, 경솔한)
# - tp09 : calm (침착한), emotionally stable (감정적으로 흔들리지 않는)
# - tp10 : conventional (평범한), uncreative (창의적이지 않은)

# %%
import pandas as pd

train=pd.read_csv('./train.csv')
test=pd.read_csv('./test_x.csv')

# %% [markdown]
# # Feature 설명
# 1. Q_A / Q_E : 알파벳에 대한 응답과 응답까지 걸린 시간 (Q_A : 1 ~ 5 사이로 응답)
# 2. age_group : 연령
# 3. education : 교육 수준
#     - 1 : Less than high school : 중학교
#     - 2 : High school : 고등학교
#     - 3 : University degree : 대학교 졸업
#     - 4 : Graduate degree : 대학원 졸업
# 4. engnat : 모국어가 영어
#     - 1 : Yes
#     - 2 : No
#     - 3 : 무응답
# 5. familysize : 형제자매 수
# 6. gender : 성별
#     - Male / Female
# 7. hand : 필기하는 손
#     - 0 : 무응답
#     - 1 : Right
#     - 2 : Left
#     - 3 : Both
# 8. married : 혼인상태
#     - 0 : Other
#     - 1 : Never married
#     - 2 : Curently married
#     - 3 : Previously married
# 9. race : 인종
#     - Asian / Arab / Black / Indigenous australian / Native American / White / Ohter
# 10. religion : 종교
#     - Agnostic / Atheist / Buddhist / Christian_Catholic / Christian_Mormon / Christian_Protestant / Christian_Other / Hindu / Jewish / Muslim / Sikh / Other
# 11. tp__ : 나는 다음 단어와 관련이 깊다 (1 ~ 7 사이로 응답)
# 12. urban : 유년기의 거주 구역
#     - 0 : 무응답
#     - 1 : Rural(country side
#     - 2 : Suburban
#     - 3 : Urban (town, city)
# 13. wr_(1~13) : 설문자의 어휘 능력 (실존하는 해당 단어의 정의를 앎)
# 14. wf_(1~3) : 설문자의 어휘 능력 (허구인 단어의 정의를 앎)

# %%
train.corr()
# Out:
#           index       QaA       QaE       QbA       QbE       QcA       QcE  \
# index  1.000000  0.004952  0.002547  0.002388 -0.000965 -0.005634 -0.007142
# QaA    0.004952  1.000000  0.009712 -0.241980  0.003238 -0.309438  0.002201
# QaE    0.002547  0.009712  1.000000 -0.010021  0.003443 -0.001002  0.021138
# QbA    0.002388 -0.241980 -0.010021  1.000000 -0.008460  0.385936 -0.016725
# QbE   -0.000965  0.003238  0.003443 -0.008460  1.000000 -0.012671  0.005204
# ...         ...       ...       ...       ...       ...       ...       ...
# wr_09 -0.003116 -0.027163  0.009145 -0.006372 -0.004665  0.028129 -0.006853
# wr_10  0.005149 -0.015936 -0.003320 -0.024496 -0.001870  0.007025 -0.006873
# wr_11  0.001034  0.000456  0.008363 -0.012131 -0.007654  0.026792 -0.005001
# wr_12  0.001107 -0.014155 -0.000173 -0.024029  0.001616  0.004300 -0.000639
# wr_13  0.002262 -0.013171 -0.000102  0.000519 -0.015458  0.003499 -0.008801
#
# ...

# %% [markdown]
# # 데이터 전처리

# %%
import numpy as np
train = train.drop(train[train.familysize > 20].index)
test = test.drop(test[test.familysize > 20].index)

# %% [markdown]
# # 원핫 인코딩 (gender, race, religion)

# %%
train=pd.get_dummies(train, columns=['race'])
train=pd.get_dummies(train, columns=['religion'])
train=pd.get_dummies(train, columns=['gender'])
test=pd.get_dummies(test, columns=['race'])
test=pd.get_dummies(test, columns=['religion'])
test=pd.get_dummies(test, columns=['gender'])

# %% [markdown]
# # Feature : Mach_score (마키아벨리니즘 스코어)

# %%
Answers = ['QaA', 'QbA', 'QcA', 'QdA', 'QeA',
             'QfA', 'QgA', 'QhA', 'QiA', 'QjA', 
             'QkA', 'QlA', 'QmA', 'QnA', 'QoA', 
             'QpA', 'QqA', 'QrA', 'QsA', 'QtA']

# %%
train[Answers].corr()
# Out:
#           QaA       QbA       QcA       QdA       QeA       QfA       QgA  \
# QaA  1.000000 -0.242039 -0.309533  0.313148  0.211464  0.278135  0.284090
# QbA -0.242039  1.000000  0.385922 -0.207661 -0.197211 -0.230834 -0.213799
# QcA -0.309533  0.385922  1.000000 -0.245295 -0.194027 -0.251566 -0.273691
# QdA  0.313148 -0.207661 -0.245295  1.000000  0.177202  0.289353  0.286227
# QeA  0.211464 -0.197211 -0.194027  0.177202  1.000000  0.216226  0.163653
# QfA  0.278135 -0.230834 -0.251566  0.289353  0.216226  1.000000  0.335666
# QgA  0.284090 -0.213799 -0.273691  0.286227  0.163653  0.335666  1.000000
# QhA -0.206719  0.335362  0.290492 -0.141037 -0.115271 -0.145191 -0.162457
# QiA  0.298700 -0.334690 -0.331254  0.259276  0.221543  0.415201  0.294311
# QjA -0.271797  0.415960  0.435363 -0.224653 -0.177270 -0.211781 -0.228652
# QkA  0.306786 -0.400696 -0.356699  0.253941  0.194835  0.396561  0.314724
# QlA -0.139458  0.150664  0.129681 -0.157918 -0.113322 -0.241944 -0.147198
# ...

# %% [markdown]
# # VIF (다중 공선성 확인) <= (10~15)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['VIF Factor'] = [variance_inflation_factor(train[Answers].values, i) for i in range(train[Answers].shape[1])]
vif['features']=train[Answers].columns
vif.round(1)
# Out:
#     VIF Factor features
# 0          5.7      QaA
# 1          6.9      QbA
# 2         10.9      QcA
# 3          4.8      QdA
# 4          4.2      QeA
# 5          6.1      QfA
# 6          5.0      QgA
# 7          4.4      QhA
# 8          8.8      QiA
# 9         12.0      QjA
# 10        13.9      QkA
# 11        13.6      QlA
# 12        10.5      QmA
# 13         8.2      QnA
# 14         9.3      QoA
# 15         7.5      QpA
# 16         7.6      QqA
# 17         6.9      QrA
# 18         9.8      QsA
# 19        10.0      QtA

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns
plt.figure(figsize=(15,15))
sns.heatmap(data = train[Answers].corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='seismic')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 1. B를 기준으로 음수인것들 : A, D, E, F, G, I, K, L, N, Q, R
# - 2. 문항이 Secret이 되어 있는 것들 : A, D, G, I, L, N, P, T
# - 3. 1-2 를 한 나머지들 : E, F, K, Q, R
# - 4. 음의 방향인 것들을 모두 양수로 바꿈

# %%
reverse = ["QeA", "QfA", "QkA", "QqA", "QrA"]
for r in reverse: 
        train[r] = 6 - train[r]
        test[r] = 6 - test[r]

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = train[Answers].corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='seismic')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 나머지 음의 방향인 것들도 모두 reverse 처리

# %%
reverse = ["QaA", "QdA", "QgA", "QiA", "QnA"]
for r in reverse: 
        train[r] = 6 - train[r]
        test[r] = 6 - test[r]

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = train[Answers].corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
train['Mach_score'] = train[Answers].mean(axis = 1)
test['Mach_score'] = test[Answers].mean(axis = 1)
train.head()
# Out:
#    index  QaA   QaE  QbA   QbE  QcA   QcE  QdA   QdE  QeA  ...  \
# 0      0  3.0   363  4.0  1370  5.0   997  5.0  1024  4.0  ...
# 1      1  1.0   647  5.0  1313  3.0  3387  1.0  2969  5.0  ...
# 2      2  2.0  1623  1.0  1480  1.0  1021  2.0  3374  1.0  ...
# 3      3  3.0   504  3.0  2311  4.0   992  3.0  3245  5.0  ...
# 4      4  5.0   927  1.0   707  5.0   556  4.0  1062  5.0  ...
#
#    religion_Christian_Other  religion_Christian_Protestant  religion_Hindu  \
# 0                         0                              0               0
# 1                         0                              0               1
# 2                         0                              0               0
# 3                         0                              0               1
# 4                         0                              0               0
#
#    religion_Jewish  religion_Muslim  religion_Other  religion_Sikh  \
# ...

# %%
train[['Mach_score']].describe()
# Out:
#          Mach_score
# count  45522.000000
# mean       3.352569
# std        0.794676
# min        1.000000
# 25%        2.750000
# 50%        3.350000
# 75%        3.950000
# max        5.000000

# %%
# %matplotlib inline
import seaborn as sns
sns.displot(train, x="Mach_score", bins=100)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set() # setting seaborn default for plots

def bar_chart(feature):
    yes = train[train['voted']==1][feature].value_counts()
    no = train[train['voted']==2][feature].value_counts()
    df = pd.DataFrame([yes,no])
    df.index = ['Yes','No']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %% [markdown]
# # Feature : tp0106, tp0207, tp0308, tp0409, tp0510 (관련있는 tp 끼리 묶음)

# %%
Tp = ['tp01', 'tp02', 'tp03', 'tp04', 'tp05',
             'tp06', 'tp07', 'tp08', 'tp09', 'tp10']
train[Tp].corr()
# Out:
#           tp01      tp02      tp03      tp04      tp05      tp06      tp07  \
# tp01  1.000000  0.030281  0.110231 -0.113552  0.284479 -0.533613  0.224226
# tp02  0.030281  1.000000 -0.036041  0.153243  0.009885 -0.014762 -0.253608
# tp03  0.110231 -0.036041  1.000000 -0.131628  0.122005  0.050903  0.096560
# tp04 -0.113552  0.153243 -0.131628  1.000000 -0.110944  0.133451  0.129731
# tp05  0.284479  0.009885  0.122005 -0.110944  1.000000 -0.096860  0.163606
# tp06 -0.533613 -0.014762  0.050903  0.133451 -0.096860  1.000000 -0.035985
# tp07  0.224226 -0.253608  0.096560  0.129731  0.163606 -0.035985  1.000000
# tp08 -0.032251  0.129973 -0.382274  0.201098  0.044030  0.041908  0.002994
# tp09  0.097129 -0.136122  0.299215 -0.499473  0.162031  0.086129  0.053695
# tp10 -0.121035  0.032966  0.005013  0.067529 -0.207972  0.144020 -0.046674
#
#           tp08      tp09      tp10
# tp01 -0.032251  0.097129 -0.121035
# tp02  0.129973 -0.136122  0.032966
# tp03 -0.382274  0.299215  0.005013
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = train[Tp].corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Spectral')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - tp01, tp06 이 반대 성향
# - tp02, tp07 이 반대 성향
# - tp03, tp08 이 반대 성향
# - tp04, tp09 이 반대 성향
# - tp05, tp10 이 반대 성향
#
# - tp06 ~ tp10을 reverse 시킨 후 tp01 ~ tp05와 매칭하여 새로운 feature 생성

# %%
reverse = ["tp06", "tp07", "tp08", "tp09", "tp10"]
for r in reverse: 
        train[r] = 8 - train[r]
        test[r] = 8 - test[r]
        
tp0106=['tp01', 'tp06']
tp0207=['tp02', 'tp07']
tp0308=['tp03', 'tp08']
tp0409=['tp04', 'tp09']
tp0510=['tp05', 'tp10']
train['tp0106'] = train[tp0106].mean(axis = 1)
train['tp0207'] = train[tp0207].mean(axis = 1)
train['tp0308'] = train[tp0308].mean(axis = 1)
train['tp0409'] = train[tp0409].mean(axis = 1)
train['tp0510'] = train[tp0510].mean(axis = 1)
temp=['tp0106', 'tp0207', 'tp0308','tp0409', 'tp0510']

test['tp0106'] = test[tp0106].mean(axis = 1)
test['tp0207'] = test[tp0207].mean(axis = 1)
test['tp0308'] = test[tp0308].mean(axis = 1)
test['tp0409'] = test[tp0409].mean(axis = 1)
test['tp0510'] = test[tp0510].mean(axis = 1)
train[temp].corr()
# Out:
#           tp0106    tp0207    tp0308    tp0409    tp0510
# tp0106  1.000000 -0.074354  0.046261 -0.088899  0.233361
# tp0207 -0.074354  1.000000 -0.099271  0.078935 -0.089888
# tp0308  0.046261 -0.099271  1.000000 -0.287526  0.039040
# tp0409 -0.088899  0.078935 -0.287526  1.000000 -0.102720
# tp0510  0.233361 -0.089888  0.039040 -0.102720  1.000000

# %% [markdown]
# # wr_(1~13) : 설문자의 어휘 능력 (실존하는 해당 단어의 정의를 앎)

# %%
import numpy as np
wr=['wr_01', 'wr_02', 'wr_03', 'wr_04', 'wr_05', 'wr_06', 'wr_07', 'wr_08', 'wr_09', 'wr_10', 'wr_11', 'wr_12', 'wr_13']
train['wr']=train[wr].mean(axis=1)
test['wr']=test[wr].mean(axis=1)
train['wr']= np.where(train['wr'] >= 0.5, 1, 0)
test['wr']= np.where(test['wr'] >= 0.5, 1, 0)
print(train['wr'])
print(test['wr'])
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 45527    1
# 45528    1
# 45529    1
# 45530    1
# 45531    1
# Name: wr, Length: 45522, dtype: int32
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 11378    1
# 11379    1
# 11380    1
# 11381    1
# 11382    0
# Name: wr, Length: 11382, dtype: int32

# %% [markdown]
# # wf_(1~3) : 설문자의 어휘 능력 (허구인 단어의 정의를 앎)

# %%
wf=['wf_01', 'wf_02', 'wf_03']
train['wf']=train[wf].mean(axis=1)
train['wf']= np.where(train['wf'] <= 0.0, 1, 0)

test['wf']=test[wf].mean(axis=1)
test['wf']= np.where(test['wf'] <= 0.0, 1, 0)
print(train['wf'])
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
#         ..
# 45527    0
# 45528    0
# 45529    1
# 45530    1
# 45531    0
# Name: wf, Length: 45522, dtype: int32

# %% [markdown]
# # Feature : Word_score (설문자의 어휘 능력 스코어)

# %%
Word=['wr', 'wf']
train['Word_score']=train[Word].mean(axis=1)
train['Word_score']= np.where(train['Word_score'] == 1.0, 1, 0)

test['Word_score']=test[Word].mean(axis=1)
test['Word_score']= np.where(test['Word_score'] == 1.0, 1, 0)
print(train['Word_score'])
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 45527    0
# 45528    0
# 45529    1
# 45530    1
# 45531    0
# Name: Word_score, Length: 45522, dtype: int32

# %% [markdown]
# # 1. 언어능력이 떨어지는 사람은 투표를 상대적으로 덜 할것이다.

# %%
sns.countplot(x="Word_score",hue=train['voted'], data=train)
plt.show()

# %% [markdown]
# # 2. 종교와 투표의 상관성 = X

# %%
religion=['religion_Agnostic','religion_Atheist', 'religion_Buddhist','religion_Christian_Catholic','religion_Christian_Mormon',
              'religion_Christian_Other', 'religion_Christian_Protestant','religion_Hindu','religion_Jewish','religion_Muslim',
              'religion_Other','religion_Sikh']
for i in religion:
    sns.countplot(x=i,hue=train['voted'], data=train)
    plt.show()

# %% [markdown]
# # 3. 성향소개(tp)와 투표의 상관성 = X

# %%
temp=['tp0106', 'tp0207', 'tp0308','tp0409', 'tp0510']
for i in temp:
    sns.countplot(x=i,hue=train['voted'], data=train)
    plt.show()

# %% [markdown]
# # 가설 4. 연령대와 투표의 상관성 = O

# %%
sns.countplot(x='age_group',hue=train['voted'], data=train)
plt.show()

# %% [markdown]
# # 가설 5. 교육수준과 투표의 상관성 = O

# %%
sns.countplot(x='education',hue=train['voted'], data=train)
plt.show()

# %% [markdown]
# # 가설 6. 성별과 투표의 상관성 = X

# %%
gender=['gender_Male', 'gender_Female']
for i in gender:
    sns.countplot(x=i,hue=train['voted'], data=train)
    plt.show()

# %% [markdown]
# # 가설 7. 결혼여부와 투표의 상관성 = ?
# - 2인 가족일 경우 투표율이 높게 나올 수 있음
# - 3인 이상 가족일 경우부터는 자녀의 투표여부도 포함 되기 때문에 유의미한 지표가 아닐수도?

# %%
sns.countplot(x='married',hue=train['voted'], data=train)
plt.show()

# %%
sns.countplot(x='age_group',hue=train['voted'], data=train)
plt.show()

# %% [markdown]
# # 나머지 feature들 drop

# %%
left_feature=['QaA', 'QbA', 'QcA', 'QdA', 'QeA','QfA', 'QgA', 'QhA', 'QiA', 'QjA', 'QkA', 'QlA', 'QmA', 'QnA', 'QoA','QpA', 
              'QqA', 'QrA', 'QsA', 'QtA','QaE', 'QbE', 'QcE', 'QdE', 'QeE', 'QfE', 'QgE', 'QhE', 'QiE', 'QjE', 'QkE', 'QlE', 
              'QmE', 'QnE', 'QoE', 'QpE', 'QqE', 'QrE', 'QsE', 'QtE','engnat','tp01', 'tp02', 'tp03', 'tp04', 'tp05','tp06', 
              'tp07', 'tp08', 'tp09', 'tp10','hand','race_Arab', 'race_Asian','race_Black','race_Indigenous Australian',
              'race_Native American','race_Other','race_White','religion_Agnostic','religion_Atheist', 'religion_Buddhist',
              'religion_Christian_Catholic','religion_Christian_Mormon', 'religion_Christian_Other', 'religion_Christian_Protestant',
              'religion_Hindu','religion_Jewish','religion_Muslim', 'religion_Other','religion_Sikh','wr_01', 'wr_02', 'wr_03', 
              'wr_04', 'wr_05', 'wr_06', 'wr_07', 'wr_08', 'wr_09', 'wf_01', 'wf_02', 'wf_03','wr_10', 'wr_11', 'wr_12', 'wr_13']

train = train.drop(left_feature, axis = 1)
test = test.drop(left_feature, axis = 1)

# %% [markdown]
# # Model 생성

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
train = train.drop('index', axis = 1)
test = test.drop('index', axis = 1)

# %% [markdown]
# # Auto ML

# %%
from pycaret.classification import *
clf = setup(data = train, target = 'voted')
# Out:
# <style type="text/css">
# #T_7c943_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7c943">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c943_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7c943_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c943_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c943_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7c943_row0_col1" class="data row0 col1" >2768</td>
#     </tr>
#     <tr>
#       <th id="T_7c943_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c943_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7c943_row1_col1" class="data row1 col1" >voted</td>
#     </tr>
#     <tr>
#       <th id="T_7c943_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# # 모델 학습 및 비교 (Train models and compare)

# %%
best_3 = compare_models(sort = 'AUC', n_select = 3)
# Out:
# <style type="text/css">
# #T_eb76c th {
#   text-align: left;
# }
# ...

# %% [markdown]
# # 모델 앙상블 (Model Ensemble)

# %%
blended = blend_models(estimator_list = best_3, fold = 5, method = 'soft')
# Out:
# <style type="text/css">
# #T_00b2b_row5_col0, #T_00b2b_row5_col1, #T_00b2b_row5_col2, #T_00b2b_row5_col3, #T_00b2b_row5_col4, #T_00b2b_row5_col5, #T_00b2b_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_00b2b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00b2b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_00b2b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_00b2b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_00b2b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_00b2b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_00b2b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_00b2b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %% [markdown]
# # 모델 예측 (Prediction)

# %%
pred_holdout = predict_model(blended)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7778e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7778e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7778e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7778e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7778e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7778e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7778e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7778e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7778e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7778e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7778e_row0_col0" class="data row0 col0" >Voting Classifier</td>
# ...

# %% [markdown]
# # 전체 데이터에 대한 재학습 (Re-training the model on whole data)

# %%
final_model = finalize_model(blended)

# %%
pred_holdout = predict_model(final_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_87ec6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87ec6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_87ec6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_87ec6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_87ec6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_87ec6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_87ec6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_87ec6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_87ec6_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87ec6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87ec6_row0_col0" class="data row0 col0" >Voting Classifier</td>
# ...

# %% [markdown]
# # 대회용 test set에 대한 예측 (Predicting on test set for the competition)

# %%
print("train :",train.shape)
print("test :",test.shape)
# Out:
# train : (45522, 17)
# test : (11382, 16)

# %%
predictions = predict_model(final_model, data = test)
predictions
# Out:
#        age_group  education  familysize  married  urban  gender_Female  \
# 0       0.837250        2.0         3.0      1.0    2.0            0.0
# 1       0.837250        2.0         2.0      1.0    3.0            0.0
# 2       0.411156        3.0         7.0      2.0    1.0            0.0
# 3       0.271357        4.0         4.0      2.0    2.0            0.0
# 4       0.837250        2.0         3.0      1.0    2.0            0.0
# ...          ...        ...         ...      ...    ...            ...
# 11378   0.469667        3.0         3.0      1.0    0.0            1.0
# 11379   0.837250        2.0         1.0      1.0    2.0            1.0
# 11380   0.411156        4.0         4.0      2.0    1.0            0.0
# 11381   0.357822        2.0         3.0      2.0    2.0            1.0
# 11382   0.469667        4.0         2.0      1.0    3.0            1.0
#
#        gender_Male  Mach_score  tp0106  tp0207  tp0308  tp0409  tp0510   wr  \
# ...

# %%
submission= pd.read_csv('./sample_submission.csv')

# %%
submission['voted'] = predictions['Score']

# %%
submission.to_csv('submission_proba.csv', index = False)

# %%
submission['voted'].max()
submission['voted'].min()
# Out:
# 0.5001

# %%
submission['V']= np.where(submission['voted'] >= 0.62, 1, 0)

# %%
submission['V']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 11378    1
# 11379    1
# 11380    1
# 11381    1
# 11382    1
# Name: V, Length: 11383, dtype: int32

# %%
submission['V'].value_counts()
# Out:
# 1    8581
# 0    2802
# Name: V, dtype: int64
