# %% [markdown]
# # 마키아벨리니즘 테스트 문항
# - A : Secret
# - B : 범죄자들과 다른 일반 사람들의 가장 큰 차이점은, 범죄자들이 잡힐만큼 멍청하다는 것이다.
# - C : 누군가를 완전히 믿는 사람은 고생을 자처하는 것이다.
# - D : Secret
# - E : P.T. Barnum이 '매 분마다 선천적으로 잘 속는 사람이 태어난다' 라고 말한 것은 틀립니다.
# - F : 누군가에게 거짓말을 하는 것은 변명의 여지가 없다.
# - G : Secret
# - H : 대부분의 사람들은 그들의 재산을 잃은 것보다 부모의 죽음을 더 빨리 잊는다.
# - I : Secret
# - J : 모든 사람에게는 악한 경향이 있고, 기회만 주어진다면 그 성향이 표현된다고 가정하는것이 가장 안전하다.
# - K : 대체로 겸손하고 정직한 것이, 중요하고 부정직 한것보다 낫다.
# - L : Secret
# - M : 여기저기를 질러가지 않는다면 앞으로 나아가기 힘들다 (요령이 없다면 앞으로 나아가기 힘들다).
# - N : Secret
# - O : 사람을 다루는 가장 좋은 방법은 그들이 듣기 원하는 말을 해주는 것이다.
# - P : Secret
# - Q : 대부분의 사람들은 기본적으로 선하며, 착하다.
# - R : 도덕적으로 올바른 일 일때만, 그 행동을 해야 한다.
# - S : 중요한 사람들(자신의 상관, 정부의 요인들 등등)애개 아첨하는것이 현명하다.
# - T : Secret
#
# ### 비 식별화를 위해 Secret 처리된 문항
# - Never tell anyone the real reason you did something unless it is useful to do so.
# - 당신이 어떤 일을 한 이유를 필요할 때를 제외하고는 누구에게도 절대 말하지 않는다.
#
# - Honesty is the best policy in all cases.
# - 모든 케이스에 있어서 정직이 최선이다.
#
# - Generally speaking, people won't work hard unless they're forced to do so.
# - 일반적으로, 사람들을 강제하지 않는 한, 열심히 일하지 않는다.
#
# - When you ask someone to do something for you, it is best to give the real reasons for wanting it rather than giving reasons which carry more weight.
# - 어떤 일을 해달라고 누군가에게 요청할 때, 내가 그 일을 원하는 실제 이유를 알려주는 것이, 더 중요해보이는 듯한 이유를 알려주는 것보다 가장 좋은 방법이다.
#
# - Most people who get ahead in the world lead clean, moral lives.
# - 세상을 앞에서 이끌어가는 사람들은 깨끗하고 도덕적인 삶을 산다.
#
# - Most people are brave.
# - 대부분의 사람들은 용감하다.
#
# - It is possible to be good in all respects.
# - 모든 면에서 좋은 것이 가능하다.
#
# - People suffering from incurable diseases should have the choice of being put painlessly to death.
# - 불치병에 걸린 사람들에게 안락사를 선택할 권리를 갖게 해야 한다.

# %% [markdown]
# # 시각화

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set() # setting seaborn default for plots

def bar_chart(feature):
    yes = train[train['voted']==1][feature].value_counts()
    no = train[train['voted']==2][feature].value_counts()
    df = pd.DataFrame([yes,no])
    df.index = ['Yes','No']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %% [markdown]
# - tp01 : extraverted (외향적), enthusiastic (열광적인)
# - tp02 : critical (비판적인), quarrelsome (걸핏하면 싸우려 드는)
# - tp03 : dependable (믿을 수 있는), self-disciplined (자기훈련이 된)
# - tp04 : anxious (불안해하는), easily upset (쉽게 흥분하는)
# - tp05 : open to new experiences, complex (새로운 경험, 집합체에 열려있는)
# - tp06 : reserved (내성적인), quiet (조용한)
# - tp07 : sympathetic (공감하는, 호감가는), warm (따뜻한)
# - tp08 : disorganized (체계적이지 않은), careless (부주의한, 경솔한)
# - tp09 : calm (침착한), emotionally stable (감정적으로 흔들리지 않는)
# - tp10 : conventional (평범한), uncreative (창의적이지 않은)

# %%
import pandas as pd

train=pd.read_csv('./train.csv')
test=pd.read_csv('./test_x.csv')

# %% [markdown]
# # Feature 설명
# 1. Q_A / Q_E : 알파벳에 대한 응답과 응답까지 걸린 시간 (Q_A : 1 ~ 5 사이로 응답)
# 2. age_group : 연령
# 3. education : 교육 수준
#     - 1 : Less than high school : 중학교
#     - 2 : High school : 고등학교
#     - 3 : University degree : 대학교 졸업
#     - 4 : Graduate degree : 대학원 졸업
# 4. engnat : 모국어가 영어
#     - 1 : Yes
#     - 2 : No
#     - 3 : 무응답
# 5. familysize : 형제자매 수
# 6. gender : 성별
#     - Male / Female
# 7. hand : 필기하는 손
#     - 0 : 무응답
#     - 1 : Right
#     - 2 : Left
#     - 3 : Both
# 8. married : 혼인상태
#     - 0 : Other
#     - 1 : Never married
#     - 2 : Curently married
#     - 3 : Previously married
# 9. race : 인종
#     - Asian / Arab / Black / Indigenous australian / Native American / White / Ohter
# 10. religion : 종교
#     - Agnostic / Atheist / Buddhist / Christian_Catholic / Christian_Mormon / Christian_Protestant / Christian_Other / Hindu / Jewish / Muslim / Sikh / Other
# 11. tp__ : 나는 다음 단어와 관련이 깊다 (1 ~ 7 사이로 응답)
# 12. urban : 유년기의 거주 구역
#     - 0 : 무응답
#     - 1 : Rural(country side
#     - 2 : Suburban
#     - 3 : Urban (town, city)
# 13. wr_(1~13) : 설문자의 어휘 능력 (실존하는 해당 단어의 정의를 앎)
# 14. wf_(1~3) : 설문자의 어휘 능력 (허구인 단어의 정의를 앎)

# %%
train.corr()
# Out:
#           index       QaA       QaE       QbA       QbE       QcA       QcE  \
# index  1.000000  0.004952  0.002547  0.002388 -0.000965 -0.005634 -0.007142
# QaA    0.004952  1.000000  0.009712 -0.241980  0.003238 -0.309438  0.002201
# QaE    0.002547  0.009712  1.000000 -0.010021  0.003443 -0.001002  0.021138
# QbA    0.002388 -0.241980 -0.010021  1.000000 -0.008460  0.385936 -0.016725
# QbE   -0.000965  0.003238  0.003443 -0.008460  1.000000 -0.012671  0.005204
# ...         ...       ...       ...       ...       ...       ...       ...
# wr_09 -0.003116 -0.027163  0.009145 -0.006372 -0.004665  0.028129 -0.006853
# wr_10  0.005149 -0.015936 -0.003320 -0.024496 -0.001870  0.007025 -0.006873
# wr_11  0.001034  0.000456  0.008363 -0.012131 -0.007654  0.026792 -0.005001
# wr_12  0.001107 -0.014155 -0.000173 -0.024029  0.001616  0.004300 -0.000639
# wr_13  0.002262 -0.013171 -0.000102  0.000519 -0.015458  0.003499 -0.008801
#
#             QdA       QdE       QeA  ...     wr_04     wr_05     wr_06  \
# index -0.004332  0.006361  0.003040  ...  0.005797 -0.004531 -0.008943
# QaA    0.313172  0.011194  0.211496  ... -0.032308 -0.031038 -0.042923
# QaE    0.000375  0.003094  0.001131  ... -0.000156 -0.000278  0.006009
# QbA   -0.207616 -0.009166 -0.197120  ...  0.016439 -0.021135  0.002244
# QbE    0.001156  0.005433  0.006908  ... -0.000932 -0.001328  0.002108
# ...         ...       ...       ...  ...       ...       ...       ...
# wr_09 -0.047089 -0.004690 -0.050873  ...  0.131079  0.107231  0.327351
# wr_10 -0.047415 -0.003171 -0.041892  ...  0.351294  0.453839  0.081429
# wr_11 -0.050704 -0.015566 -0.072944  ...  0.250671  0.222746  0.298060
# wr_12 -0.043512 -0.007181 -0.034397  ...  0.318048  0.390937  0.084020
# wr_13 -0.067613 -0.022053 -0.063945  ...  0.426806  0.479021  0.103997
#
#           wr_07     wr_08     wr_09     wr_10     wr_11     wr_12     wr_13
# index  0.003536  0.004703 -0.003116  0.005149  0.001034  0.001107  0.002262
# QaA   -0.026785  0.004128 -0.027163 -0.015936  0.000456 -0.014155 -0.013171
# QaE   -0.003558  0.000097  0.009145 -0.003320  0.008363 -0.000173 -0.000102
# QbA   -0.000924 -0.014666 -0.006372 -0.024496 -0.012131 -0.024029  0.000519
# QbE   -0.001553 -0.001615 -0.004665 -0.001870 -0.007654  0.001616 -0.015458
# ...         ...       ...       ...       ...       ...       ...       ...
# wr_09  0.051140 -0.001071  1.000000  0.049036  0.348387  0.050239  0.071570
# wr_10  0.579492  0.465421  0.049036  1.000000  0.133251  0.497165  0.431927
# wr_11  0.143939  0.068122  0.348387  0.133251  1.000000  0.129087  0.170115
# wr_12  0.474846  0.418815  0.050239  0.497165  0.129087  1.000000  0.404597
# wr_13  0.447438  0.370145  0.071570  0.431927  0.170115  0.404597  1.000000
#
# [74 rows x 74 columns]

# %% [markdown]
# # 연령대 feature 문자열 제거

# %%
#train['age_group']=train['age_group'].apply(lambda x : float(x[:2]))
test['age_group']=test['age_group'].apply(lambda x : float(x[:2]))

# %% [markdown]
# # 원핫 인코딩 (gender, race, religion)

# %%
train=pd.get_dummies(train, columns=['race'])
train=pd.get_dummies(train, columns=['religion'])
train=pd.get_dummies(train, columns=['gender'])
test=pd.get_dummies(test, columns=['race'])
test=pd.get_dummies(test, columns=['religion'])
test=pd.get_dummies(test, columns=['gender'])

# %% [markdown]
# # Feature : Mach_score (마키아벨리니즘 스코어)

# %%
Answers = ['QaA', 'QbA', 'QcA', 'QdA', 'QeA',
             'QfA', 'QgA', 'QhA', 'QiA', 'QjA', 
             'QkA', 'QlA', 'QmA', 'QnA', 'QoA', 
             'QpA', 'QqA', 'QrA', 'QsA', 'QtA']

# %%
train[Answers].corr()
# Out:
#           QaA       QbA       QcA       QdA       QeA       QfA       QgA  \
# QaA  1.000000 -0.241980 -0.309438  0.313172  0.211496  0.278128  0.284088
# QbA -0.241980  1.000000  0.385936 -0.207616 -0.197120 -0.230640 -0.213849
# QcA -0.309438  0.385936  1.000000 -0.245332 -0.194034 -0.251508 -0.273718
# QdA  0.313172 -0.207616 -0.245332  1.000000  0.177335  0.289385  0.286276
# QeA  0.211496 -0.197120 -0.194034  0.177335  1.000000  0.216240  0.163681
# QfA  0.278128 -0.230640 -0.251508  0.289385  0.216240  1.000000  0.335580
# QgA  0.284088 -0.213849 -0.273718  0.286276  0.163681  0.335580  1.000000
# QhA -0.206606  0.335355  0.290533 -0.141015 -0.115286 -0.145183 -0.162458
# QiA  0.298739 -0.334574 -0.331125  0.259297  0.221493  0.415221  0.294329
# QjA -0.271789  0.416002  0.435447 -0.224679 -0.177303 -0.211676 -0.228686
# QkA  0.306749 -0.400663 -0.356694  0.253929  0.194804  0.396567  0.314729
# QlA -0.139342  0.150751  0.129842 -0.157913 -0.113245 -0.241877 -0.147158
# QmA -0.257046  0.364109  0.342382 -0.258631 -0.164973 -0.303960 -0.248646
# QnA  0.312220 -0.306211 -0.321233  0.318468  0.219749  0.586806  0.382234
# QoA -0.243123  0.390330  0.359381 -0.194442 -0.168596 -0.326198 -0.220745
# QpA -0.270471  0.384570  0.356571 -0.170144 -0.165515 -0.186758 -0.189272
# QqA  0.428917 -0.349398 -0.365697  0.319034  0.192963  0.251645  0.304300
# QrA  0.254527 -0.260459 -0.237713  0.261593  0.186968  0.381883  0.297919
# QsA -0.204179  0.326142  0.280658 -0.161672 -0.171635 -0.311158 -0.186661
# QtA -0.287804  0.469701  0.459220 -0.206086 -0.178131 -0.299630 -0.237559
#
#           QhA       QiA       QjA       QkA       QlA       QmA       QnA  \
# QaA -0.206606  0.298739 -0.271789  0.306749 -0.139342 -0.257046  0.312220
# QbA  0.335355 -0.334574  0.416002 -0.400663  0.150751  0.364109 -0.306211
# QcA  0.290533 -0.331125  0.435447 -0.356694  0.129842  0.342382 -0.321233
# QdA -0.141015  0.259297 -0.224679  0.253929 -0.157913 -0.258631  0.318468
# QeA -0.115286  0.221493 -0.177303  0.194804 -0.113245 -0.164973  0.219749
# QfA -0.145183  0.415221 -0.211676  0.396567 -0.241877 -0.303960  0.586806
# QgA -0.162458  0.294329 -0.228686  0.314729 -0.147158 -0.248646  0.382234
# QhA  1.000000 -0.237290  0.313781 -0.312070  0.093610  0.255121 -0.204967
# QiA -0.237290  1.000000 -0.300826  0.494388 -0.148326 -0.323045  0.473264
# QjA  0.313781 -0.300826  1.000000 -0.339873  0.123711  0.356087 -0.273303
# QkA -0.312070  0.494388 -0.339873  1.000000 -0.168143 -0.366239  0.493859
# QlA  0.093610 -0.148326  0.123711 -0.168143  1.000000  0.171899 -0.218838
# QmA  0.255121 -0.323045  0.356087 -0.366239  0.171899  1.000000 -0.337650
# QnA -0.204967  0.473264 -0.273303  0.493859 -0.218838 -0.337650  1.000000
# QoA  0.278404 -0.405192  0.367046 -0.421948  0.149659  0.390116 -0.367500
# QpA  0.306816 -0.288284  0.392553 -0.339563  0.103533  0.347962 -0.251002
# QqA -0.263895  0.332933 -0.386905  0.405019 -0.109789 -0.295245  0.334329
# QrA -0.201824  0.371018 -0.225617  0.423531 -0.180088 -0.239937  0.427314
# QsA  0.192402 -0.363610  0.289508 -0.374433  0.169279  0.351273 -0.329506
# QtA  0.350285 -0.443742  0.463567 -0.462664  0.128207  0.403069 -0.382128
#
#           QoA       QpA       QqA       QrA       QsA       QtA
# QaA -0.243123 -0.270471  0.428917  0.254527 -0.204179 -0.287804
# QbA  0.390330  0.384570 -0.349398 -0.260459  0.326142  0.469701
# QcA  0.359381  0.356571 -0.365697 -0.237713  0.280658  0.459220
# QdA -0.194442 -0.170144  0.319034  0.261593 -0.161672 -0.206086
# QeA -0.168596 -0.165515  0.192963  0.186968 -0.171635 -0.178131
# QfA -0.326198 -0.186758  0.251645  0.381883 -0.311158 -0.299630
# QgA -0.220745 -0.189272  0.304300  0.297919 -0.186661 -0.237559
# QhA  0.278404  0.306816 -0.263895 -0.201824  0.192402  0.350285
# QiA -0.405192 -0.288284  0.332933  0.371018 -0.363610 -0.443742
# QjA  0.367046  0.392553 -0.386905 -0.225617  0.289508  0.463567
# QkA -0.421948 -0.339563  0.405019  0.423531 -0.374433 -0.462664
# QlA  0.149659  0.103533 -0.109789 -0.180088  0.169279  0.128207
# QmA  0.390116  0.347962 -0.295245 -0.239937  0.351273  0.403069
# QnA -0.367500 -0.251002  0.334329  0.427314 -0.329506 -0.382128
# QoA  1.000000  0.371147 -0.283380 -0.249514  0.448600  0.479779
# QpA  0.371147  1.000000 -0.331096 -0.189880  0.296227  0.420123
# QqA -0.283380 -0.331096  1.000000  0.284989 -0.225559 -0.370300
# QrA -0.249514 -0.189880  0.284989  1.000000 -0.230834 -0.279325
# QsA  0.448600  0.296227 -0.225559 -0.230834  1.000000  0.365143
# QtA  0.479779  0.420123 -0.370300 -0.279325  0.365143  1.000000

# %% [markdown]
# # VIF (다중 공선성 확인) <= (10~15)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['VIF Factor'] = [variance_inflation_factor(train[Answers].values, i) for i in range(train[Answers].shape[1])]
vif['features']=train[Answers].columns
vif.round(1)
# Out:
#     VIF Factor features
# 0          5.7      QaA
# 1          6.9      QbA
# 2         10.9      QcA
# 3          4.8      QdA
# 4          4.2      QeA
# 5          6.1      QfA
# 6          5.0      QgA
# 7          4.4      QhA
# 8          8.8      QiA
# 9         12.0      QjA
# 10        13.9      QkA
# 11        13.6      QlA
# 12        10.5      QmA
# 13         8.2      QnA
# 14         9.3      QoA
# 15         7.5      QpA
# 16         7.6      QqA
# 17         6.9      QrA
# 18         9.8      QsA
# 19        10.0      QtA

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns
plt.figure(figsize=(15,15))
sns.heatmap(data = train[Answers].corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='seismic')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 1. B를 기준으로 음수인것들 : A, D, E, F, G, I, K, L, N, Q, R
# - 2. 문항이 Secret이 되어 있는 것들 : A, D, G, I, L, N, P, T
# - 3. 1-2 를 한 나머지들 : E, F, K, Q, R
# - 4. 음의 방향인 것들을 모두 양수로 바꿈

# %%
reverse = ["QeA", "QfA", "QkA", "QqA", "QrA"]
for r in reverse: 
        train[r] = 6 - train[r]
        test[r] = 6 - test[r]

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = train[Answers].corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='seismic')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 나머지 음의 방향인 것들도 모두 reverse 처리

# %%
reverse = ["QaA", "QdA", "QgA", "QiA", "QnA"]
for r in reverse: 
        train[r] = 6 - train[r]
        test[r] = 6 - test[r]

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = train[Answers].corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
train['Mach_score'] = train[Answers].mean(axis = 1)
test['Mach_score'] = test[Answers].mean(axis = 1)
train.head()
# Out:
#    index  QaA   QaE  QbA   QbE  QcA   QcE  QdA   QdE  QeA  ...  \
# 0      0  3.0   363  4.0  1370  5.0   997  5.0  1024  4.0  ...
# 1      1  1.0   647  5.0  1313  3.0  3387  1.0  2969  5.0  ...
# 2      2  2.0  1623  1.0  1480  1.0  1021  2.0  3374  1.0  ...
# 3      3  3.0   504  3.0  2311  4.0   992  3.0  3245  5.0  ...
# 4      4  5.0   927  1.0   707  5.0   556  4.0  1062  5.0  ...
#
#    religion_Christian_Other  religion_Christian_Protestant  religion_Hindu  \
# 0                         0                              0               0
# 1                         0                              0               1
# 2                         0                              0               0
# 3                         0                              0               1
# 4                         0                              0               0
#
#    religion_Jewish  religion_Muslim  religion_Other  religion_Sikh  \
# 0                0                0               1              0
# 1                0                0               0              0
# 2                0                0               1              0
# 3                0                0               0              0
# 4                0                0               0              0
#
#    gender_Female  gender_Male  Mach_score
# 0              1            0        2.95
# 1              1            0        2.60
# 2              0            1        1.90
# 3              1            0        3.35
# 4              0            1        3.00
#
# [5 rows x 97 columns]

# %%
train[['Mach_score']].describe()
# Out:
#          Mach_score
# count  45532.000000
# mean       3.352474
# std        0.794661
# min        1.000000
# 25%        2.750000
# 50%        3.350000
# 75%        3.950000
# max        5.000000

# %%
# %matplotlib inline
import seaborn as sns
sns.displot(train, x="Mach_score", bins=100)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set() # setting seaborn default for plots

def bar_chart(feature):
    yes = train[train['voted']==1][feature].value_counts()
    no = train[train['voted']==2][feature].value_counts()
    df = pd.DataFrame([yes,no])
    df.index = ['Yes','No']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %% [markdown]
# # Feature : tp0106, tp0207, tp0308, tp0409, tp0510 (관련있는 tp 끼리 묶음)

# %%
Tp = ['tp01', 'tp02', 'tp03', 'tp04', 'tp05',
             'tp06', 'tp07', 'tp08', 'tp09', 'tp10']
train[Tp].corr()
# Out:
#           tp01      tp02      tp03      tp04      tp05      tp06      tp07  \
# tp01  1.000000  0.030293  0.110243 -0.113612  0.284424 -0.533509  0.224147
# tp02  0.030293  1.000000 -0.036038  0.153299  0.009851 -0.014705 -0.253673
# tp03  0.110243 -0.036038  1.000000 -0.131611  0.122022  0.050971  0.096556
# tp04 -0.113612  0.153299 -0.131611  1.000000 -0.110948  0.133496  0.129691
# tp05  0.284424  0.009851  0.122022 -0.110948  1.000000 -0.096690  0.163600
# tp06 -0.533509 -0.014705  0.050971  0.133496 -0.096690  1.000000 -0.036021
# tp07  0.224147 -0.253673  0.096556  0.129691  0.163600 -0.036021  1.000000
# tp08 -0.032290  0.129985 -0.382249  0.201111  0.043947  0.041814  0.003018
# tp09  0.097206 -0.136112  0.299190 -0.499477  0.161917  0.085966  0.053684
# tp10 -0.121024  0.033021  0.005007  0.067519 -0.207917  0.144035 -0.046761
#
#           tp08      tp09      tp10
# tp01 -0.032290  0.097206 -0.121024
# tp02  0.129985 -0.136112  0.033021
# tp03 -0.382249  0.299190  0.005007
# tp04  0.201111 -0.499477  0.067519
# tp05  0.043947  0.161917 -0.207917
# tp06  0.041814  0.085966  0.144035
# tp07  0.003018  0.053684 -0.046761
# tp08  1.000000 -0.206891  0.040053
# tp09 -0.206891  1.000000  0.045546
# tp10  0.040053  0.045546  1.000000

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = train[Tp].corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Spectral')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - tp01, tp06 이 반대 성향
# - tp02, tp07 이 반대 성향
# - tp03, tp08 이 반대 성향
# - tp04, tp09 이 반대 성향
# - tp05, tp10 이 반대 성향
#
# - tp06 ~ tp10을 reverse 시킨 후 tp01 ~ tp05와 매칭하여 새로운 feature 생성

# %%
reverse = ["tp06", "tp07", "tp08", "tp09", "tp10"]
for r in reverse: 
        train[r] = 8 - train[r]
        test[r] = 8 - test[r]
        
tp0106=['tp01', 'tp06']
tp0207=['tp02', 'tp07']
tp0308=['tp03', 'tp08']
tp0409=['tp04', 'tp09']
tp0510=['tp05', 'tp10']
train['tp0106'] = train[tp0106].mean(axis = 1)
train['tp0207'] = train[tp0207].mean(axis = 1)
train['tp0308'] = train[tp0308].mean(axis = 1)
train['tp0409'] = train[tp0409].mean(axis = 1)
train['tp0510'] = train[tp0510].mean(axis = 1)
temp=['tp0106', 'tp0207', 'tp0308','tp0409', 'tp0510']

test['tp0106'] = test[tp0106].mean(axis = 1)
test['tp0207'] = test[tp0207].mean(axis = 1)
test['tp0308'] = test[tp0308].mean(axis = 1)
test['tp0409'] = test[tp0409].mean(axis = 1)
test['tp0510'] = test[tp0510].mean(axis = 1)
train[temp].corr()
# Out:
#           tp0106    tp0207    tp0308    tp0409    tp0510
# tp0106  1.000000 -0.074353  0.046224 -0.089011  0.233300
# tp0207 -0.074353  1.000000 -0.099263  0.078964 -0.089960
# tp0308  0.046224 -0.099263  1.000000 -0.287484  0.039089
# tp0409 -0.089011  0.078964 -0.287484  1.000000 -0.102691
# tp0510  0.233300 -0.089960  0.039089 -0.102691  1.000000

# %% [markdown]
# # wr_(1~13) : 설문자의 어휘 능력 (실존하는 해당 단어의 정의를 앎)

# %%
import numpy as np
wr=['wr_01', 'wr_02', 'wr_03', 'wr_04', 'wr_05', 'wr_06', 'wr_07', 'wr_08', 'wr_09', 'wr_10', 'wr_11', 'wr_12', 'wr_13']
train['wr']=train[wr].mean(axis=1)
test['wr']=test[wr].mean(axis=1)
train['wr']= np.where(train['wr'] >= 0.5, 1, 0)
test['wr']= np.where(test['wr'] >= 0.5, 1, 0)
print(train['wr'])
print(test['wr'])
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 45527    1
# 45528    1
# 45529    1
# 45530    1
# 45531    1
# Name: wr, Length: 45532, dtype: int32
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 11378    1
# 11379    1
# 11380    1
# 11381    1
# 11382    0
# Name: wr, Length: 11383, dtype: int32

# %% [markdown]
# # wf_(1~3) : 설문자의 어휘 능력 (허구인 단어의 정의를 앎)

# %%
wf=['wf_01', 'wf_02', 'wf_03']
train['wf']=train[wf].mean(axis=1)
train['wf']= np.where(train['wf'] <= 0.0, 1, 0)

test['wf']=test[wf].mean(axis=1)
test['wf']= np.where(test['wf'] <= 0.0, 1, 0)
print(train['wf'])
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
#         ..
# 45527    0
# 45528    0
# 45529    1
# 45530    1
# 45531    0
# Name: wf, Length: 45532, dtype: int32

# %% [markdown]
# # Feature : Word_score (설문자의 어휘 능력 스코어)

# %%
Word=['wr', 'wf']
train['Word_score']=train[Word].mean(axis=1)
train['Word_score']= np.where(train['Word_score'] == 1.0, 1, 0)

test['Word_score']=test[Word].mean(axis=1)
test['Word_score']= np.where(test['Word_score'] == 1.0, 1, 0)
print(train['Word_score'])
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 45527    0
# 45528    0
# 45529    1
# 45530    1
# 45531    0
# Name: Word_score, Length: 45532, dtype: int32

# %% [markdown]
# # 1. 언어능력이 떨어지는 사람은 투표를 상대적으로 덜 할것이다.

# %%
sns.countplot(x="Word_score",hue=train['voted'], data=train)
plt.show()

# %% [markdown]
# # 2. 종교와 투표의 상관성 = X

# %%
religion=['religion_Agnostic','religion_Atheist', 'religion_Buddhist','religion_Christian_Catholic','religion_Christian_Mormon',
              'religion_Christian_Other', 'religion_Christian_Protestant','religion_Hindu','religion_Jewish','religion_Muslim',
              'religion_Other','religion_Sikh']
for i in religion:
    sns.countplot(x=i,hue=train['voted'], data=train)
    plt.show()

# %% [markdown]
# # 3. 성향소개(tp)와 투표의 상관성 = X

# %%
temp=['tp0106', 'tp0207', 'tp0308','tp0409', 'tp0510']
for i in temp:
    sns.countplot(x=i,hue=train['voted'], data=train)
    plt.show()

# %% [markdown]
# # 가설 4. 연령대와 투표의 상관성 = O

# %%
sns.countplot(x='age_group',hue=train['voted'], data=train)
plt.show()

# %% [markdown]
# # 가설 5. 교육수준과 투표의 상관성 = O

# %%
sns.countplot(x='education',hue=train['voted'], data=train)
plt.show()

# %% [markdown]
# # 가설 6. 성별과 투표의 상관성 = X

# %%
gender=['gender_Male', 'gender_Female']
for i in gender:
    sns.countplot(x=i,hue=train['voted'], data=train)
    plt.show()

# %% [markdown]
# # 가설 7. 결혼여부와 투표의 상관성 = ?
# - 2인 가족일 경우 투표율이 높게 나올 수 있음
# - 3인 이상 가족일 경우부터는 자녀의 투표여부도 포함 되기 때문에 유의미한 지표가 아닐수도?

# %%
sns.countplot(x='married',hue=train['voted'], data=train)
plt.show()

# %% [markdown]
# # 나머지 feature들 간의 상관관계 파악

# %%
left_feature=['QaA', 'QbA', 'QcA', 'QdA', 'QeA','QfA', 'QgA', 'QhA', 'QiA', 'QjA', 'QkA', 'QlA', 'QmA', 'QnA', 'QoA','QpA', 
              'QqA', 'QrA', 'QsA', 'QtA','QaE', 'QbE', 'QcE', 'QdE', 'QeE', 'QfE', 'QgE', 'QhE', 'QiE', 'QjE', 'QkE', 'QlE', 
              'QmE', 'QnE', 'QoE', 'QpE', 'QqE', 'QrE', 'QsE', 'QtE','engnat','tp01', 'tp02', 'tp03', 'tp04', 'tp05','tp06', 
              'tp07', 'tp08', 'tp09', 'tp10','hand', 'race_Arab', 'race_Asian','race_Black','race_Indigenous Australian',
              'race_Native American','race_Other','race_White','religion_Agnostic','religion_Atheist', 'religion_Buddhist',
              'religion_Christian_Catholic','religion_Christian_Mormon', 'religion_Christian_Other', 'religion_Christian_Protestant',
              'religion_Hindu','religion_Jewish','religion_Muslim', 'religion_Other','religion_Sikh','wr_01', 'wr_02', 'wr_03', 
              'wr_04', 'wr_05', 'wr_06', 'wr_07', 'wr_08', 'wr_09', 'wf_01', 'wf_02', 'wf_03','wr_10', 'wr_11', 'wr_12', 'wr_13']

train = train.drop(left_feature, axis = 1)
test = test.drop(left_feature, axis = 1)

# %% [markdown]
# # Model 생성

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
train = train.drop('index', axis = 1)
test = test.drop('index', axis = 1)

# %% [markdown]
# # Auto ML

# %%
from pycaret.classification import *
clf = setup(data = train, target = 'voted')
# Out:
# <style type="text/css">
# #T_933fb_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_933fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_933fb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_933fb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_933fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_933fb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_933fb_row0_col1" class="data row0 col1" >4120</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_933fb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_933fb_row1_col1" class="data row1 col1" >voted</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_933fb_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_933fb_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_933fb_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_933fb_row3_col1" class="data row3 col1" >1: 0, 2: 1</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_933fb_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_933fb_row4_col1" class="data row4 col1" >(45532, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_933fb_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_933fb_row5_col1" class="data row5 col1" >(45532, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_933fb_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_933fb_row6_col1" class="data row6 col1" >(31872, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_933fb_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_933fb_row7_col1" class="data row7 col1" >(13660, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_933fb_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_933fb_row8_col1" class="data row8 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_933fb_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_933fb_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_933fb_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_933fb_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_933fb_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_933fb_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_933fb_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_933fb_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_933fb_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_933fb_row13_col1" class="data row13 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_933fb_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_933fb_row14_col1" class="data row14 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_933fb_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_933fb_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_933fb_row16_col0" class="data row16 col0" >Low variance threshold</td>
#       <td id="T_933fb_row16_col1" class="data row16 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_933fb_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_933fb_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_933fb_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_933fb_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_933fb_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_933fb_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_933fb_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_933fb_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_933fb_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_933fb_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_933fb_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_933fb_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_933fb_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_933fb_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_933fb_row23_col1" class="data row23 col1" >696d</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 모델 학습 및 비교 (Train models and compare)

# %%
best_3 = compare_models(sort = 'AUC', n_select = 3)
# Out:
# <style type="text/css">
# #T_eda5f th {
#   text-align: left;
# }
# #T_eda5f_row0_col0, #T_eda5f_row0_col1, #T_eda5f_row0_col3, #T_eda5f_row0_col4, #T_eda5f_row0_col5, #T_eda5f_row0_col6, #T_eda5f_row0_col7, #T_eda5f_row1_col0, #T_eda5f_row1_col1, #T_eda5f_row1_col2, #T_eda5f_row1_col3, #T_eda5f_row1_col4, #T_eda5f_row1_col5, #T_eda5f_row1_col6, #T_eda5f_row1_col7, #T_eda5f_row2_col0, #T_eda5f_row2_col1, #T_eda5f_row2_col2, #T_eda5f_row2_col3, #T_eda5f_row2_col4, #T_eda5f_row2_col5, #T_eda5f_row2_col6, #T_eda5f_row2_col7, #T_eda5f_row3_col0, #T_eda5f_row3_col1, #T_eda5f_row3_col2, #T_eda5f_row3_col3, #T_eda5f_row3_col4, #T_eda5f_row3_col5, #T_eda5f_row3_col6, #T_eda5f_row3_col7, #T_eda5f_row4_col0, #T_eda5f_row4_col1, #T_eda5f_row4_col2, #T_eda5f_row4_col3, #T_eda5f_row4_col5, #T_eda5f_row4_col6, #T_eda5f_row5_col0, #T_eda5f_row5_col1, #T_eda5f_row5_col2, #T_eda5f_row5_col3, #T_eda5f_row5_col4, #T_eda5f_row5_col5, #T_eda5f_row5_col6, #T_eda5f_row5_col7, #T_eda5f_row6_col0, #T_eda5f_row6_col1, #T_eda5f_row6_col2, #T_eda5f_row6_col3, #T_eda5f_row6_col5, #T_eda5f_row6_col6, #T_eda5f_row7_col0, #T_eda5f_row7_col1, #T_eda5f_row7_col2, #T_eda5f_row7_col3, #T_eda5f_row7_col5, #T_eda5f_row7_col6, #T_eda5f_row8_col0, #T_eda5f_row8_col1, #T_eda5f_row8_col2, #T_eda5f_row8_col3, #T_eda5f_row8_col5, #T_eda5f_row8_col6, #T_eda5f_row9_col0, #T_eda5f_row9_col1, #T_eda5f_row9_col2, #T_eda5f_row9_col3, #T_eda5f_row9_col4, #T_eda5f_row9_col5, #T_eda5f_row9_col6, #T_eda5f_row9_col7, #T_eda5f_row10_col0, #T_eda5f_row10_col1, #T_eda5f_row10_col2, #T_eda5f_row10_col3, #T_eda5f_row10_col4, #T_eda5f_row10_col5, #T_eda5f_row10_col6, #T_eda5f_row10_col7, #T_eda5f_row11_col0, #T_eda5f_row11_col1, #T_eda5f_row11_col2, #T_eda5f_row11_col4, #T_eda5f_row11_col6, #T_eda5f_row11_col7, #T_eda5f_row12_col0, #T_eda5f_row12_col1, #T_eda5f_row12_col2, #T_eda5f_row12_col3, #T_eda5f_row12_col4, #T_eda5f_row12_col5, #T_eda5f_row12_col6, #T_eda5f_row12_col7, #T_eda5f_row13_col0, #T_eda5f_row13_col2, #T_eda5f_row13_col3, #T_eda5f_row13_col4, #T_eda5f_row13_col5, #T_eda5f_row13_col7 {
#   text-align: left;
# }
# #T_eda5f_row0_col2, #T_eda5f_row4_col4, #T_eda5f_row4_col7, #T_eda5f_row6_col4, #T_eda5f_row6_col7, #T_eda5f_row7_col4, #T_eda5f_row7_col7, #T_eda5f_row8_col4, #T_eda5f_row8_col7, #T_eda5f_row11_col3, #T_eda5f_row11_col5, #T_eda5f_row13_col1, #T_eda5f_row13_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_eda5f_row0_col8, #T_eda5f_row1_col8, #T_eda5f_row2_col8, #T_eda5f_row3_col8, #T_eda5f_row4_col8, #T_eda5f_row5_col8, #T_eda5f_row6_col8, #T_eda5f_row7_col8, #T_eda5f_row8_col8, #T_eda5f_row9_col8, #T_eda5f_row10_col8, #T_eda5f_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_eda5f_row11_col8, #T_eda5f_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_eda5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eda5f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_eda5f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_eda5f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_eda5f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_eda5f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_eda5f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_eda5f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_eda5f_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_eda5f_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eda5f_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_eda5f_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_eda5f_row0_col1" class="data row0 col1" >0.6738</td>
#       <td id="T_eda5f_row0_col2" class="data row0 col2" >0.7422</td>
#       <td id="T_eda5f_row0_col3" class="data row0 col3" >0.6068</td>
#       <td id="T_eda5f_row0_col4" class="data row0 col4" >0.7490</td>
#       <td id="T_eda5f_row0_col5" class="data row0 col5" >0.6704</td>
#       <td id="T_eda5f_row0_col6" class="data row0 col6" >0.3545</td>
#       <td id="T_eda5f_row0_col7" class="data row0 col7" >0.3623</td>
#       <td id="T_eda5f_row0_col8" class="data row0 col8" >0.0350</td>
#     </tr>
#     <tr>
#       <th id="T_eda5f_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_eda5f_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_eda5f_row1_col1" class="data row1 col1" >0.6673</td>
#       <td id="T_eda5f_row1_col2" class="data row1 col2" >0.7332</td>
#       <td id="T_eda5f_row1_col3" class="data row1 col3" >0.6131</td>
#       <td id="T_eda5f_row1_col4" class="data row1 col4" >0.7350</td>
#       <td id="T_eda5f_row1_col5" class="data row1 col5" >0.6683</td>
#       <td id="T_eda5f_row1_col6" class="data row1 col6" >0.3400</td>
#       <td id="T_eda5f_row1_col7" class="data row1 col7" >0.3458</td>
#       <td id="T_eda5f_row1_col8" class="data row1 col8" >0.2090</td>
#     </tr>
#     <tr>
#       <th id="T_eda5f_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_eda5f_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_eda5f_row2_col1" class="data row2 col1" >0.6625</td>
#       <td id="T_eda5f_row2_col2" class="data row2 col2" >0.7314</td>
#       <td id="T_eda5f_row2_col3" class="data row2 col3" >0.6916</td>
#       <td id="T_eda5f_row2_col4" class="data row2 col4" >0.6934</td>
#       <td id="T_eda5f_row2_col5" class="data row2 col5" >0.6912</td>
#       <td id="T_eda5f_row2_col6" class="data row2 col6" >0.3187</td>
#       <td id="T_eda5f_row2_col7" class="data row2 col7" >0.3201</td>
#       <td id="T_eda5f_row2_col8" class="data row2 col8" >0.6590</td>
#     </tr>
#     <tr>
#       <th id="T_eda5f_level0_row3" class="row_heading level0 row3" >qda</th>
#       <td id="T_eda5f_row3_col0" class="data row3 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_eda5f_row3_col1" class="data row3 col1" >0.4766</td>
#       <td id="T_eda5f_row3_col2" class="data row3 col2" >0.6852</td>
#       <td id="T_eda5f_row3_col3" class="data row3 col3" >0.0666</td>
#       <td id="T_eda5f_row3_col4" class="data row3 col4" >0.7398</td>
#       <td id="T_eda5f_row3_col5" class="data row3 col5" >0.0816</td>
#       <td id="T_eda5f_row3_col6" class="data row3 col6" >0.0368</td>
#       <td id="T_eda5f_row3_col7" class="data row3 col7" >0.0595</td>
#       <td id="T_eda5f_row3_col8" class="data row3 col8" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_eda5f_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_eda5f_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_eda5f_row4_col1" class="data row4 col1" >0.6648</td>
#       <td id="T_eda5f_row4_col2" class="data row4 col2" >0.6839</td>
#       <td id="T_eda5f_row4_col3" class="data row4 col3" >0.4805</td>
#       <td id="T_eda5f_row4_col4" class="data row4 col4" >0.8372</td>
#       <td id="T_eda5f_row4_col5" class="data row4 col5" >0.6105</td>
#       <td id="T_eda5f_row4_col6" class="data row4 col6" >0.3523</td>
#       <td id="T_eda5f_row4_col7" class="data row4 col7" >0.3945</td>
#       <td id="T_eda5f_row4_col8" class="data row4 col8" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_eda5f_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_eda5f_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_eda5f_row5_col1" class="data row5 col1" >0.6631</td>
#       <td id="T_eda5f_row5_col2" class="data row5 col2" >0.6838</td>
#       <td id="T_eda5f_row5_col3" class="data row5 col3" >0.4914</td>
#       <td id="T_eda5f_row5_col4" class="data row5 col4" >0.8204</td>
#       <td id="T_eda5f_row5_col5" class="data row5 col5" >0.6146</td>
#       <td id="T_eda5f_row5_col6" class="data row5 col6" >0.3473</td>
#       <td id="T_eda5f_row5_col7" class="data row5 col7" >0.3837</td>
#       <t

# %% [markdown]
# # 모델 앙상블 (Model Ensemble)

# %%
blended = blend_models(estimator_list = best_3, fold = 5, method = 'soft')
# Out:
# <style type="text/css">
# #T_5559f_row5_col0, #T_5559f_row5_col1, #T_5559f_row5_col2, #T_5559f_row5_col3, #T_5559f_row5_col4, #T_5559f_row5_col5, #T_5559f_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5559f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5559f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5559f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5559f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5559f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5559f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5559f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5559f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5559f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5559f_row0_col0" class="data row0 col0" >0.6668</td>
#       <td id="T_5559f_row0_col1" class="data row0 col1" >0.7363</td>
#       <td id="T_5559f_row0_col2" class="data row0 col2" >0.5944</td>
#       <td id="T_5559f_row0_col3" class="data row0 col3" >0.7448</td>
#       <td id="T_5559f_row0_col4" class="data row0 col4" >0.6611</td>
#       <td id="T_5559f_row0_col5" class="data row0 col5" >0.3415</td>
#       <td id="T_5559f_row0_col6" class="data row0 col6" >0.3499</td>
#     </tr>
#     <tr>
#       <th id="T_5559f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5559f_row1_col0" class="data row1 col0" >0.6753</td>
#       <td id="T_5559f_row1_col1" class="data row1 col1" >0.7448</td>
#       <td id="T_5559f_row1_col2" class="data row1 col2" >0.6322</td>
#       <td id="T_5559f_row1_col3" class="data row1 col3" >0.7366</td>
#       <td id="T_5559f_row1_col4" class="data row1 col4" >0.6805</td>
#       <td id="T_5559f_row1_col5" class="data row1 col5" >0.3543</td>
#       <td id="T_5559f_row1_col6" class="data row1 col6" >0.3586</td>
#     </tr>
#     <tr>
#       <th id="T_5559f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5559f_row2_col0" class="data row2 col0" >0.6743</td>
#       <td id="T_5559f_row2_col1" class="data row2 col1" >0.7476</td>
#       <td id="T_5559f_row2_col2" class="data row2 col2" >0.6690</td>
#       <td id="T_5559f_row2_col3" class="data row2 col3" >0.7167</td>
#       <td id="T_5559f_row2_col4" class="data row2 col4" >0.6920</td>
#       <td id="T_5559f_row2_col5" class="data row2 col5" >0.3473</td>
#       <td id="T_5559f_row2_col6" class="data row2 col6" >0.3482</td>
#     </tr>
#     <tr>
#       <th id="T_5559f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5559f_row3_col0" class="data row3 col0" >0.6740</td>
#       <td id="T_5559f_row3_col1" class="data row3 col1" >0.7504</td>
#       <td id="T_5559f_row3_col2" class="data row3 col2" >0.6261</td>
#       <td id="T_5559f_row3_col3" class="data row3 col3" >0.7379</td>
#       <td id="T_5559f_row3_col4" class="data row3 col4" >0.6774</td>
#       <td id="T_5559f_row3_col5" class="data row3 col5" >0.3523</td>
#       <td id="T_5559f_row3_col6" class="data row3 col6" >0.3572</td>
#     </tr>
#     <tr>
#       <th id="T_5559f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5559f_row4_col0" class="data row4 col0" >0.6721</td>
#       <td id="T_5559f_row4_col1" class="data row4 col1" >0.7456</td>
#       <td id="T_5559f_row4_col2" class="data row4 col2" >0.6347</td>
#       <td id="T_5559f_row4_col3" class="data row4 col3" >0.7303</td>
#       <td id="T_5559f_row4_col4" class="data row4 col4" >0.6792</td>
#       <td id="T_5559f_row4_col5" class="data row4 col5" >0.3472</td>
#       <td id="T_5559f_row4_col6" class="data row4 col6" >0.3508</td>
#     </tr>
#     <tr>
#       <th id="T_5559f_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_5559f_row5_col0" class="data row5 col0" >0.6725</td>
#       <td id="T_5559f_row5_col1" class="data row5 col1" >0.7449</td>
#       <td id="T_5559f_row5_col2" class="data row5 col2" >0.6313</td>
#       <td id="T_5559f_row5_col3" class="data row5 col3" >0.7333</td>
#       <td id="T_5559f_row5_col4" class="data row5 col4" >0.6780</td>
#       <td id="T_5559f_row5_col5" class="data row5 col5" >0.3485</td>
#       <td id="T_5559f_row5_col6" class="data row5 col6" >0.3530</td>
#     </tr>
#     <tr>
#       <th id="T_5559f_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_5559f_row6_col0" class="data row6 col0" >0.0030</td>
#       <td id="T_5559f_row6_col1" class="data row6 col1" >0.0047</td>
#       <td id="T_5559f_row6_col2" class="data row6 col2" >0.0238</td>
#       <td id="T_5559f_row6_col3" class="data row6 col3" >0.0095</td>
#       <td id="T_5559f_row6_col4" class="data row6 col4" >0.0099</td>
#       <td id="T_5559f_row6_col5" class="data row6 col5" >0.0045</td>
#       <td id="T_5559f_row6_col6" class="data row6 col6" >0.0041</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 모델 예측 (Prediction)

# %%
pred_holdout = predict_model(blended)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4801f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4801f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4801f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_4801f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_4801f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_4801f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_4801f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_4801f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_4801f_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4801f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4801f_row0_col0" class="data row0 col0" >Voting Classifier</td>
#       <td id="T_4801f_row0_col1" class="data row0 col1" >0.6698</td>
#       <td id="T_4801f_row0_col2" class="data row0 col2" >0.7358</td>
#       <td id="T_4801f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4801f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4801f_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_4801f_row0_col6" class="data row0 col6" >0.3428</td>
#       <td id="T_4801f_row0_col7" class="data row0 col7" >0.3464</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 전체 데이터에 대한 재학습 (Re-training the model on whole data)

# %%
final_model = finalize_model(blended)

# %% [markdown]
# # 대회용 test set에 대한 예측 (Predicting on test set for the competition)

# %%
print("train :",train.shape)
print("test :",test.shape)
# Out:
# train : (45532, 17)
# test : (11383, 16)

# %%
predictions = predict_model(final_model, data = test)
predictions
# Out:
#        age_group  education  familysize  married  urban  gender_Female  \
# 0       0.546824        2.0         3.0      1.0    2.0            0.0
# 1       0.546824        2.0         2.0      1.0    3.0            0.0
# 2       0.546824        3.0         7.0      2.0    1.0            0.0
# 3       0.546824        4.0         4.0      2.0    2.0            0.0
# 4       0.546824        2.0         3.0      1.0    2.0            0.0
# ...          ...        ...         ...      ...    ...            ...
# 11378   0.546824        3.0         3.0      1.0    0.0            1.0
# 11379   0.546824        2.0         1.0      1.0    2.0            1.0
# 11380   0.546824        4.0         4.0      2.0    1.0            0.0
# 11381   0.546824        2.0         3.0      2.0    2.0            1.0
# 11382   0.546824        4.0         2.0      1.0    3.0            1.0
#
#        gender_Male  Mach_score  tp0106  tp0207  tp0308  tp0409  tp0510   wr  \
# 0              1.0        2.45     4.0     3.5     3.0     4.0     2.5  0.0
# 1              1.0        2.80     4.0     4.0     4.0     4.0     4.0  0.0
# 2              1.0        3.55     6.5     4.0     4.5     2.0     6.5  1.0
# 3              1.0        3.35     1.0     6.5     2.0     6.5     1.0  1.0
# 4              1.0        2.90     7.0     2.0     4.0     3.0     4.0  1.0
# ...            ...         ...     ...     ...     ...     ...     ...  ...
# 11378          0.0        3.20     2.5     3.5     4.0     3.5     1.5  1.0
# 11379          0.0        4.55     2.0     4.0     5.0     1.0     2.0  1.0
# 11380          1.0        3.15     5.0     4.5     1.5     7.0     2.0  1.0
# 11381          0.0        3.05     5.0     6.5     1.5     6.5     1.5  1.0
# 11382          0.0        3.40     4.5     5.0     2.5     1.5     1.0  0.0
#
#         wf  Word_score  Label   Score
# 0      1.0         0.0      2  0.5331
# 1      1.0         0.0      2  0.6215
# 2      1.0         1.0      1  0.5311
# 3      1.0         1.0      1  0.6951
# 4      1.0         1.0      2  0.5582
# ...    ...         ...    ...     ...
# 11378  1.0         1.0      1  0.6059
# 11379  0.0         0.0      2  0.6251
# 11380  0.0         0.0      1  0.7703
# 11381  1.0         1.0      1  0.5162
# 11382  1.0         0.0      1  0.5426
#
# [11383 rows x 18 columns]

# %%
submission= pd.read_csv('./sample_submission.csv')

# %%
submission['voted'] = predictions['Score']

# %%
submission.to_csv('submission_proba.csv', index = False)

# %%
submission.max()
# Out:
# index    11382.0000
# voted        0.7969
# dtype: float64

# %%
submission['V']= np.where(submission['voted'] >= 0.62, 1, 0)

# %%
submission['V']
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 11378    0
# 11379    1
# 11380    1
# 11381    1
# 11382    0
# Name: V, Length: 11383, dtype: int32
